# %%
import os

def process_labels(labels_file, output_dir):
    """
    Process the labels.txt file and create individual label files for each image
    with only selected parameters (class number, class name, bounding box coordinates).
    
    :param labels_file: Path to the labels.txt file.
    :param output_dir: Directory to save the individual label files.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Read the labels file
    with open(labels_file, 'r') as file:
        lines = file.readlines()
    
    # Group labels by image index
    grouped_labels = {}
    for line in lines:
        parts = line.strip().split()
        image_index = int(parts[0])  # Extract the image index (first value in the line)
        class_number = parts[1]
        class_name = parts[2]
        bbox_coords = parts[6:10]  # Bounding box coordinates: x_min, y_min, x_max, y_max
        
        # Combine into the desired format
        filtered_label = f"{class_number} {class_name} {' '.join(bbox_coords)}"
        
        if image_index not in grouped_labels:
            grouped_labels[image_index] = []
        grouped_labels[image_index].append(filtered_label)
    
    # Write individual label files
    for image_index, labels in grouped_labels.items():
        filename = f"{image_index:06d}.txt"  # Create a filename like 000000.txt
        output_path = os.path.join(output_dir, filename)
        with open(output_path, 'w') as output_file:
            output_file.write("\n".join(labels))
    
    print(f"Processed labels and saved them to {output_dir}")

# Example usage
labels_file = "valid1/labels1.txt"  # Replace with the actual path to your labels.txt file
output_dir = "valid1/labels"  # Replace with the desired output directory
process_labels(labels_file, output_dir)
# Out:
# Processed labels and saved them to valid1/labels

# %%
def process_labels(labels_file, output_dir):
    """
    Process the labels.txt file and append labels to existing label files if they already exist.
    Handles image filenames with 10-digit zero-padded numbers.
    
    :param labels_file: Path to the labels.txt file.
    :param output_dir: Directory containing the existing label files.
    """
    # Read the labels file
    with open(labels_file, 'r') as file:
        lines = file.readlines()
    
    # Group labels by image index
    grouped_labels = {}
    for line in lines:
        parts = line.strip().split()
        image_index = int(parts[0])  # Extract the image index (first value in the line)
        class_number = parts[1]
        class_name = parts[2]
        bbox_coords = parts[6:10]  # Bounding box coordinates: x_min, y_min, x_max, y_max
        
        # Combine into the desired format
        filtered_label = f"{class_number} {class_name} {' '.join(bbox_coords)}"
        
        if image_index not in grouped_labels:
            grouped_labels[image_index] = []
        grouped_labels[image_index].append(filtered_label)
    
    # Append to or create label files
    for image_index, labels in grouped_labels.items():
        filename = f"{image_index:010d}.txt"  # Filename like 0000000001.txt
        output_path = os.path.join(output_dir, filename)
        
        # Append to the file if it exists; otherwise, create a new one
        with open(output_path, 'a') as output_file:  # Use 'a' mode to append
            output_file.write("\n".join(labels) + "\n")
    
    print(f"Processed labels and appended them to {output_dir}")

# Example usage
labels_file = "valid1/labels2.txt"  # Replace with the actual path to your labels.txt file
output_dir = "valid1/labels"  # Replace with the directory containing existing label files
process_labels(labels_file, output_dir)
# Out:
# Processed labels and appended them to valid1/labels

# %%
import os

def update_class_numbers(label_dir):
    """
    Update class numbers in existing label files based on the class name.
    
    :param label_dir: Directory containing the label files to update.
    """
    # Class mapping: Class name -> Class number
    class_mapping = {
        "Car": "0",
        "Cyclist": "1",
        "Pedestrian": "2"
    }
    
    # Iterate over all files in the directory
    for filename in os.listdir(label_dir):
        if filename.endswith(".txt"):
            file_path = os.path.join(label_dir, filename)
            
            # Read the content of the file
            with open(file_path, 'r') as file:
                lines = file.readlines()
            
            # Update class numbers
            updated_lines = []
            for line in lines:
                parts = line.strip().split()
                if len(parts) < 6:
                    continue  # Skip lines that don't have enough data
                current_class_number = parts[0]
                class_name = parts[1]
                
                # Assign the correct class number
                if class_name in class_mapping:
                    correct_class_number = class_mapping[class_name]
                    parts[0] = correct_class_number  # Update the class number
                    updated_lines.append(" ".join(parts))
                else:
                    # Keep the line unchanged if class name is not in the mapping
                    updated_lines.append(line.strip())
            
            # Overwrite the file with updated content
            with open(file_path, 'w') as file:
                file.write("\n".join(updated_lines) + "\n")
    
    print(f"Updated class numbers in all label files in {label_dir}")

# Example usage
label_dir = "valid1/labels"  # Replace with the directory containing your label files
update_class_numbers(label_dir)
# Out:
# Updated class numbers in all label files in valid1/labels

# %%
def normalize_labels(label_dir, image_dir, output_dir, class_mapping):
    """
    Normalize labels to YOLO format: <class_id> <cx> <cy> <w> <h>.
    
    :param label_dir: Directory containing raw label files.
    :param image_dir: Directory containing corresponding images (for dimensions).
    :param output_dir: Directory to save normalized labels.
    :param class_mapping: Dictionary mapping class names to IDs.
    """
    os.makedirs(output_dir, exist_ok=True)
    
    for filename in os.listdir(label_dir):
        if filename.endswith(".txt"):
            label_path = os.path.join(label_dir, filename)
            image_path = os.path.join(image_dir, filename.replace(".txt", ".png"))  # Adjust if using another extension
            output_path = os.path.join(output_dir, filename)
            
            # Check if corresponding image exists
            if not os.path.exists(image_path):
                print(f"Warning: Image {image_path} not found for {label_path}. Skipping.")
                continue
            
            # Get image dimensions
            try:
                from PIL import Image
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Error: Unable to open image {image_path}. {e}")
                continue
            
            # Read and process label file
            with open(label_path, 'r') as file:
                lines = file.readlines()
            
            normalized_labels = []
            for line in lines:
                parts = line.strip().split()
                if len(parts) < 6:
                    print(f"Skipping malformed line in {label_path}: {line.strip()}")
                    continue
                
                try:
                    # Extract class ID and bounding box coordinates
                    class_name = parts[1]
                    if class_name not in class_mapping:
                        print(f"Skipping unknown class '{class_name}' in {label_path}: {line.strip()}")
                        continue
                    
                    class_id = class_mapping[class_name]
                    x_min, y_min, x_max, y_max = map(float, parts[2:6])
                    
                    # Normalize bounding box
                    x_center = ((x_min + x_max) / 2) / img_width
                    y_center = ((y_min + y_max) / 2) / img_height
                    width = (x_max - x_min) / img_width
                    height = (y_max - y_min) / img_height
                    
                    # Append to normalized labels
                    normalized_labels.append(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")
                except ValueError as e:
                    print(f"Error processing line in {label_path}: {line.strip()} ({e})")
            
            # Write normalized labels to output file
            if normalized_labels:
                with open(output_path, 'w') as file:
                    file.write("\n".join(normalized_labels) + "\n")
                print(f"Normalized labels for {label_path} -> {output_path}")
            else:
                print(f"No valid labels found in {label_path}. File will be left empty.")

# Example usage
label_dir = "valid1/labels"  # Directory with raw labels
image_dir = "valid1/images"  # Directory with corresponding images
output_dir = "valid1/labels"  # Directory to save normalized labels
class_mapping = {
    "Car": "0",
    "Cyclist": "1",
    "Pedestrian": "2"
}

normalize_labels(label_dir, image_dir, output_dir, class_mapping)
# Out:
# Normalized labels for valid1/labels\000000.txt -> valid1/labels\000000.txt
# Normalized labels for valid1/labels\0000000000.txt -> valid1/labels\0000000000.txt
# Normalized labels for valid1/labels\0000000001.txt -> valid1/labels\0000000001.txt
# Normalized labels for valid1/labels\0000000002.txt -> valid1/labels\0000000002.txt
# Normalized labels for valid1/labels\0000000003.txt -> valid1/labels\0000000003.txt
# Normalized labels for valid1/labels\0000000004.txt -> valid1/labels\0000000004.txt
# Normalized labels for valid1/labels\0000000005.txt -> valid1/labels\0000000005.txt
# Normalized labels for valid1/labels\0000000006.txt -> valid1/labels\0000000006.txt
# Normalized labels for valid1/labels\0000000007.txt -> valid1/labels\0000000007.txt
# Normalized labels for valid1/labels\0000000008.txt -> valid1/labels\0000000008.txt
# Normalized labels for valid1/labels\0000000009.txt -> valid1/labels\0000000009.txt
# Normalized labels for valid1/labels\0000000010.txt -> valid1/labels\0000000010.txt
# Normalized labels for valid1/labels\0000000011.txt -> valid1/labels\0000000011.txt
# Normalized labels for valid1/labels\0000000012.txt -> valid1/labels\0000000012.txt
# Normalized labels for valid1/labels\0000000013.txt -> valid1/labels\0000000013.txt
# Normalized labels for valid1/labels\0000000014.txt -> valid1/labels\0000000014.txt
# Normalized labels for valid1/labels\0000000015.txt -> valid1/labels\0000000015.txt
# Normalized labels for valid1/labels\0000000016.txt -> valid1/labels\0000000016.txt
# Normalized labels for valid1/labels\0000000017.txt -> valid1/labels\0000000017.txt
# Normalized labels for valid1/labels\0000000018.txt -> valid1/labels\0000000018.txt
# Normalized labels for valid1/labels\0000000019.txt -> valid1/labels\0000000019.txt
# Normalized labels for valid1/labels\0000000020.txt -> valid1/labels\0000000020.txt
# Normalized labels for valid1/labels\0000000021.txt -> valid1/labels\0000000021.txt
# Normalized labels for valid1/labels\0000000022.txt -> valid1/labels\0000000022.txt
# Normalized labels for valid1/labels\0000000023.txt -> valid1/labels\0000000023.txt
# Normalized labels for valid1/labels\0000000024.txt -> valid1/labels\0000000024.txt
# Normalized labels for valid1/labels\0000000025.txt -> valid1/labels\0000000025.txt
# Normalized labels for valid1/labels\0000000026.txt -> valid1/labels\0000000026.txt
# Normalized labels for valid1/labels\0000000027.txt -> valid1/labels\0000000027.txt
# Normalized labels for valid1/labels\0000000028.txt -> valid1/labels\0000000028.txt
# Normalized labels for valid1/labels\0000000029.txt -> valid1/labels\0000000029.txt
# Normalized labels for valid1/labels\0000000030.txt -> valid1/labels\0000000030.txt
# Normalized labels for valid1/labels\0000000031.txt -> valid1/labels\0000000031.txt
# Normalized labels for valid1/labels\0000000032.txt -> valid1/labels\0000000032.txt
# Normalized labels for valid1/labels\0000000033.txt -> valid1/labels\0000000033.txt
# Normalized labels for valid1/labels\0000000034.txt -> valid1/labels\0000000034.txt
# Normalized labels for valid1/labels\0000000035.txt -> valid1/labels\0000000035.txt
# Normalized labels for valid1/labels\0000000036.txt -> valid1/labels\0000000036.txt
# Normalized labels for valid1/labels\0000000037.txt -> valid1/labels\0000000037.txt
# Normalized labels for valid1/labels\0000000038.txt -> valid1/labels\0000000038.txt
# Normalized labels for valid1/labels\0000000039.txt -> valid1/labels\0000000039.txt
# Normalized labels for valid1/labels\0000000040.txt -> valid1/labels\0000000040.txt
# Normalized labels for valid1/labels\0000000041.txt -> valid1/labels\0000000041.txt
# Normalized labels for valid1/labels\0000000042.txt -> valid1/labels\0000000042.txt
# Normalized labels for valid1/labels\0000000043.txt -> valid1/labels\0000000043.txt
# Normalized labels for valid1/labels\0000000044.txt -> valid1/labels\0000000044.txt
# Normalized labels for valid1/labels\0000000045.txt -> valid1/labels\0000000045.txt
# Normalized labels for valid1/labels\0000000046.txt -> valid1/labels\0000000046.txt
# Normalized labels for valid1/labels\0000000047.txt -> valid1/labels\0000000047.txt
# Normalized labels for valid1/labels\0000000048.txt -> valid1/labels\0000000048.txt
# Normalized labels for valid1/labels\0000000049.txt -> valid1/labels\0000000049.txt
# Normalized labels for valid1/labels\0000000050.txt -> valid1/labels\0000000050.txt
# Normalized labels for valid1/labels\0000000051.txt -> valid1/labels\0000000051.txt
# Normalized labels for valid1/labels\0000000052.txt -> valid1/labels\0000000052.txt
# Normalized labels for valid1/labels\0000000053.txt -> valid1/labels\0000000053.txt
# Normalized labels for valid1/labels\0000000054.txt -> valid1/labels\0000000054.txt
# Normalized labels for valid1/labels\0000000055.txt -> valid1/labels\0000000055.txt
# Normalized labels for valid1/labels\0000000056.txt -> valid1/labels\0000000056.txt
# Normalized labels for valid1/labels\0000000057.txt -> valid1/labels\0000000057.txt
# Normalized labels for valid1/labels\0000000058.txt -> valid1/labels\0000000058.txt
# Normalized labels for valid1/labels\0000000059.txt -> valid1/labels\0000000059.txt
# Normalized labels for valid1/labels\0000000060.txt -> valid1/labels\0000000060.txt
# Normalized labels for valid1/labels\0000000061.txt -> valid1/labels\0000000061.txt
# Normalized labels for valid1/labels\0000000062.txt -> valid1/labels\0000000062.txt
# Normalized labels for valid1/labels\0000000063.txt -> valid1/labels\0000000063.txt
# Normalized labels for valid1/labels\0000000064.txt -> valid1/labels\0000000064.txt
# Normalized labels for valid1/labels\0000000065.txt -> valid1/labels\0000000065.txt
# Normalized labels for valid1/labels\0000000066.txt -> valid1/labels\0000000066.txt
# Normalized labels for valid1/labels\0000000067.txt -> valid1/labels\0000000067.txt
# Normalized labels for valid1/labels\0000000068.txt -> valid1/labels\0000000068.txt
# Normalized labels for valid1/labels\0000000069.txt -> valid1/labels\0000000069.txt
# Normalized labels for valid1/labels\0000000070.txt -> valid1/labels\0000000070.txt
# Normalized labels for valid1/labels\0000000071.txt -> valid1/labels\0000000071.txt
# Normalized labels for valid1/labels\0000000072.txt -> valid1/labels\0000000072.txt
# Normalized labels for valid1/labels\0000000073.txt -> valid1/labels\0000000073.txt
# Normalized labels for valid1/labels\0000000074.txt -> valid1/labels\0000000074.txt
# Normalized labels for valid1/labels\0000000075.txt -> valid1/labels\0000000075.txt
# Normalized labels for valid1/labels\0000000076.txt -> valid1/labels\0000000076.txt
# Normalized labels for valid1/labels\0000000077.txt -> valid1/labels\0000000077.txt
# Normalized labels for valid1/labels\0000000078.txt -> valid1/labels\0000000078.txt
# Normalized labels for valid1/labels\0000000079.txt -> valid1/labels\0000000079.txt
# Normalized labels for valid1/labels\0000000080.txt -> valid1/labels\0000000080.txt
# Normalized labels for valid1/labels\0000000081.txt -> valid1/labels\0000000081.txt
# Normalized labels for valid1/labels\0000000082.txt -> valid1/labels\0000000082.txt
# Normalized labels for valid1/labels\0000000083.txt -> valid1/labels\0000000083.txt
# Normalized labels for valid1/labels\0000000084.txt -> valid1/labels\0000000084.txt
# Normalized labels for valid1/labels\0000000085.txt -> valid1/labels\0000000085.txt
# Normalized labels for valid1/labels\0000000086.txt -> valid1/labels\0000000086.txt
# Normalized labels for valid1/labels\0000000087.txt -> valid1/labels\0000000087.txt
# Normalized labels for valid1/labels\0000000088.txt -> valid1/labels\0000000088.txt
# Normalized labels for valid1/labels\0000000089.txt -> valid1/labels\0000000089.txt
# Normalized labels for valid1/labels\0000000090.txt -> valid1/labels\0000000090.txt
# Normalized labels for valid1/labels\0000000091.txt -> valid1/labels\0000000091.txt
# Normalized labels for valid1/labels\0000000092.txt -> valid1/labels\0000000092.txt
# Normalized labels for valid1/labels\0000000093.txt -> valid1/labels\0000000093.txt
# Normalized labels for valid1/labels\0000000094.txt -> valid1/labels\0000000094.txt
# Normalized labels for valid1/labels\0000000095.txt -> valid1/labels\0000000095.txt
# Normalized labels for valid1/labels\0000000096.txt -> valid1/labels\0000000096.txt
# Normalized labels for valid1/labels\0000000097.txt -> valid1/labels\0000000097.txt
# Normalized labels for valid1/labels\0000000098.txt -> valid1/labels\0000000098.txt
# Normalized labels for valid1/labels\0000000099.txt -> valid1/labels\0000000099.txt
# Normalized labels for valid1/labels\0000000100.txt -> valid1/labels\0000000100.txt
# Normalized labels for valid1/labels\0000000101.txt -> valid1/labels\0000000101.txt
# Normalized labels for valid1/labels\0000000102.txt -> valid1/labels\0000000102.txt
# Normalized labels for valid1/labels\0000000103.txt -> valid1/labels\0000000103.txt
# Normalized labels for valid1/labels\0000000104.txt -> valid1/labels\0000000104.txt
# Normalized labels for valid1/labels\0000000105.txt -> valid1/labels\0000000105.txt
# Normalized labels for valid1/labels\0000000106.txt -> valid1/labels\0000000106.txt
# Normalized labels for valid1/labels\0000000107.txt -> valid1/labels\0000000107.txt
# Normalized labels for valid1/labels\0000000108.txt -> valid1/labels\0000000108.txt
# Normalized labels for valid1/labels\0000000109.txt -> valid1/labels\0000000109.txt
# Normalized labels for valid1/labels\0000000110.txt -> valid1/labels\0000000110.txt
# Normalized labels for valid1/labels\0000000111.txt -> valid1/labels\0000000111.txt
# Normalized labels for valid1/labels\0000000112.txt -> valid1/labels\0000000112.txt
# Normalized labels for valid1/labels\0000000113.txt -> valid1/labels\0000000113.txt
# Normalized labels for valid1/labels\0000000114.txt -> valid1/labels\0000000114.txt
# Normalized labels for valid1/labels\0000000115.txt -> valid1/labels\0000000115.txt
# Normalized labels for valid1/labels\0000000116.txt -> valid1/labels\0000000116.txt
# Normalized labels for valid1/labels\0000000117.txt -> valid1/labels\0000000117.txt
# Normalized labels for valid1/labels\0000000118.txt -> valid1/labels\0000000118.txt
# Normalized labels for valid1/labels\0000000119.txt -> valid1/labels\0000000119.txt
# Normalized labels for valid1/labels\0000000120.txt -> valid1/labels\0000000120.txt
# Normalized labels for valid1/labels\0000000121.txt -> valid1/labels\0000000121.txt
# Normalized labels for valid1/labels\0000000122.txt -> valid1/labels\0000000122.txt
# Normalized labels for valid1/labels\0000000123.txt -> valid1/labels\0000000123.txt
# Normalized labels for valid1/labels\0000000124.txt -> valid1/labels\0000000124.txt
# Normalized labels for valid1/labels\0000000125.txt -> valid1/labels\0000000125.txt
# Normalized labels for valid1/labels\0000000126.txt -> valid1/labels\0000000126.txt
# Normalized labels for valid1/labels\0000000127.txt -> valid1/labels\0000000127.txt
# Normalized labels for valid1/labels\0000000128.txt -> valid1/labels\0000000128.txt
# Normalized labels for valid1/labels\0000000129.txt -> valid1/labels\0000000129.txt
# Normalized labels for valid1/labels\0000000130.txt -> valid1/labels\0000000130.txt
# Normalized labels for valid1/labels\0000000131.txt -> valid1/labels\0000000131.txt
# Normalized labels for valid1/labels\0000000132.txt -> valid1/labels\0000000132.txt
# Normalized labels for valid1/labels\0000000133.txt -> valid1/labels\0000000133.txt
# Normalized labels for valid1/labels\0000000134.txt -> valid1/labels\0000000134.txt
# Normalized labels for valid1/labels\0000000135.txt -> valid1/labels\0000000135.txt
# Normalized labels for valid1/labels\0000000136.txt -> valid1/labels\0000000136.txt
# Normalized labels for valid1/labels\0000000137.txt -> valid1/labels\0000000137.txt
# Normalized labels for valid1/labels\0000000138.txt -> valid1/labels\0000000138.txt
# Normalized labels for valid1/labels\0000000139.txt -> valid1/labels\0000000139.txt
# Normalized labels for valid1/labels\0000000140.txt -> valid1/labels\0000000140.txt
# Normalized labels for valid1/labels\0000000141.txt -> valid1/labels\0000000141.txt
# Normalized labels for valid1/labels\0000000142.txt -> valid1/labels\0000000142.txt
# Normalized labels for valid1/labels\0000000143.txt -> valid1/labels\0000000143.txt
# Normalized labels for valid1/labels\0000000144.txt -> valid1/labels\0000000144.txt
# Normalized labels for valid1/labels\0000000145.txt -> valid1/labels\0000000145.txt
# Normalized labels for valid1/labels\0000000146.txt -> valid1/labels\0000000146.txt
# Normalized labels for valid1/labels\0000000147.txt -> valid1/labels\0000000147.txt
# Normalized labels for valid1/labels\0000000148.txt -> valid1/labels\0000000148.txt
# Normalized labels for valid1/labels\0000000149.txt -> valid1/labels\0000000149.txt
# Normalized labels for valid1/labels\0000000150.txt -> valid1/labels\0000000150.txt
# Normalized labels for valid1/labels\0000000151.txt -> valid1/labels\0000000151.txt
# Normalized labels for valid1/labels\0000000152.txt -> valid1/labels\0000000152.txt
# Normalized labels for valid1/labels\0000000153.txt -> valid1/labels\0000000153.txt
# Normalized labels for valid1/labels\0000000154.txt -> valid1/labels\0000000154.txt
# Normalized labels for valid1/labels\0000000155.txt -> valid1/labels\0000000155.txt
# Normalized labels for valid1/labels\0000000156.txt -> valid1/labels\0000000156.txt
# Normalized labels for valid1/labels\0000000157.txt -> valid1/labels\0000000157.txt
# Normalized labels for valid1/labels\0000000158.txt -> valid1/labels\0000000158.txt
# Normalized labels for valid1/labels\0000000159.txt -> valid1/labels\0000000159.txt
# Normalized labels for valid1/labels\0000000160.txt -> valid1/labels\0000000160.txt
# Normalized labels for valid1/labels\0000000161.txt -> valid1/labels\0000000161.txt
# Normalized labels for valid1/labels\0000000162.txt -> valid1/labels\0000000162.txt
# Normalized labels for valid1/labels\0000000163.txt -> valid1/labels\0000000163.txt
# Normalized labels for valid1/labels\0000000164.txt -> valid1/labels\0000000164.txt
# Normalized labels for valid1/labels\0000000165.txt -> valid1/labels\0000000165.txt
# Normalized labels for valid1/labels\0000000166.txt -> valid1/labels\0000000166.txt
# Normalized labels for valid1/labels\0000000167.txt -> valid1/labels\0000000167.txt
# Normalized labels for valid1/labels\0000000168.txt -> valid1/labels\0000000168.txt
# Normalized labels for valid1/labels\0000000169.txt -> valid1/labels\0000000169.txt
# Normalized labels for valid1/labels\0000000170.txt -> valid1/labels\0000000170.txt
# Normalized labels for valid1/labels\0000000171.txt -> valid1/labels\0000000171.txt
# Normalized labels for valid1/labels\0000000172.txt -> valid1/labels\0000000172.txt
# Normalized labels for valid1/labels\0000000173.txt -> valid1/labels\0000000173.txt
# Normalized labels for valid1/labels\0000000174.txt -> valid1/labels\0000000174.txt
# Normalized labels for valid1/labels\0000000175.txt -> valid1/labels\0000000175.txt
# Normalized labels for valid1/labels\0000000176.txt -> valid1/labels\0000000176.txt
# Normalized labels for valid1/labels\0000000177.txt -> valid1/labels\0000000177.txt
# Normalized labels for valid1/labels\0000000178.txt -> valid1/labels\0000000178.txt
# Normalized labels for valid1/labels\0000000179.txt -> valid1/labels\0000000179.txt
# Normalized labels for valid1/labels\0000000180.txt -> valid1/labels\0000000180.txt
# Normalized labels for valid1/labels\0000000181.txt -> valid1/labels\0000000181.txt
# Normalized labels for valid1/labels\0000000182.txt -> valid1/labels\0000000182.txt
# Normalized labels for valid1/labels\0000000183.txt -> valid1/labels\0000000183.txt
# Normalized labels for valid1/labels\0000000184.txt -> valid1/labels\0000000184.txt
# Normalized labels for valid1/labels\0000000185.txt -> valid1/labels\0000000185.txt
# Normalized labels for valid1/labels\0000000186.txt -> valid1/labels\0000000186.txt
# Normalized labels for valid1/labels\0000000187.txt -> valid1/labels\0000000187.txt
# Normalized labels for valid1/labels\0000000188.txt -> valid1/labels\0000000188.txt
# Normalized labels for valid1/labels\0000000189.txt -> valid1/labels\0000000189.txt
# Normalized labels for valid1/labels\0000000190.txt -> valid1/labels\0000000190.txt
# Normalized labels for valid1/labels\0000000191.txt -> valid1/labels\0000000191.txt
# Normalized labels for valid1/labels\0000000192.txt -> valid1/labels\0000000192.txt
# Normalized labels for valid1/labels\0000000193.txt -> valid1/labels\0000000193.txt
# Normalized labels for valid1/labels\0000000194.txt -> valid1/labels\0000000194.txt
# Normalized labels for valid1/labels\0000000195.txt -> valid1/labels\0000000195.txt
# Normalized labels for valid1/labels\0000000196.txt -> valid1/labels\0000000196.txt
# Normalized labels for valid1/labels\0000000197.txt -> valid1/labels\0000000197.txt
# Normalized labels for valid1/labels\0000000198.txt -> valid1/labels\0000000198.txt
# Normalized labels for valid1/labels\0000000199.txt -> valid1/labels\0000000199.txt
# Normalized labels for valid1/labels\0000000200.txt -> valid1/labels\0000000200.txt
# Normalized labels for valid1/labels\0000000201.txt -> valid1/labels\0000000201.txt
# Normalized labels for valid1/labels\0000000202.txt -> valid1/labels\0000000202.txt
# Normalized labels for valid1/labels\0000000203.txt -> valid1/labels\0000000203.txt
# Normalized labels for valid1/labels\0000000204.txt -> valid1/labels\0000000204.txt
# Normalized labels for valid1/labels\0000000205.txt -> valid1/labels\0000000205.txt
# Normalized labels for valid1/labels\0000000206.txt -> valid1/labels\0000000206.txt
# Normalized labels for valid1/labels\0000000207.txt -> valid1/labels\0000000207.txt
# Normalized labels for valid1/labels\0000000208.txt -> valid1/labels\0000000208.txt
# Normalized labels for valid1/labels\000001.txt -> valid1/labels\000001.txt
# Normalized labels for valid1/labels\000002.txt -> valid1/labels\000002.txt
# Normalized labels for valid1/labels\000003.txt -> valid1/labels\000003.txt
# Normalized labels for valid1/labels\000004.txt -> valid1/labels\000004.txt
# Normalized labels for valid1/labels\000005.txt -> valid1/labels\000005.txt
# Normalized labels for valid1/labels\000006.txt -> valid1/labels\000006.txt
# Normalized labels for valid1/labels\000007.txt -> valid1/labels\000007.txt
# Normalized labels for valid1/labels\000008.txt -> valid1/labels\000008.txt
# Normalized labels for valid1/labels\000009.txt -> valid1/labels\000009.txt
# Normalized labels for valid1/labels\000010.txt -> valid1/labels\000010.txt
# Normalized labels for valid1/labels\000011.txt -> valid1/labels\000011.txt
# Normalized labels for valid1/labels\000012.txt -> valid1/labels\000012.txt
# Normalized labels for valid1/labels\000013.txt -> valid1/labels\000013.txt
# Normalized labels for valid1/labels\000014.txt -> valid1/labels\000014.txt
# Normalized labels for valid1/labels\000015.txt -> valid1/labels\000015.txt
# Normalized labels for valid1/labels\000016.txt -> valid1/labels\000016.txt
# Normalized labels for valid1/labels\000017.txt -> valid1/labels\000017.txt
# Normalized labels for valid1/labels\000018.txt -> valid1/labels\000018.txt
# Normalized labels for valid1/labels\000019.txt -> valid1/labels\000019.txt
# Normalized labels for valid1/labels\000020.txt -> valid1/labels\000020.txt
# Normalized labels for valid1/labels\000021.txt -> valid1/labels\000021.txt
# Normalized labels for valid1/labels\000022.txt -> valid1/labels\000022.txt
# Normalized labels for valid1/labels\000023.txt -> valid1/labels\000023.txt
# Normalized labels for valid1/labels\000024.txt -> valid1/labels\000024.txt
# Normalized labels for valid1/labels\000025.txt -> valid1/labels\000025.txt
# Normalized labels for valid1/labels\000026.txt -> valid1/labels\000026.txt
# Normalized labels for valid1/labels\000027.txt -> valid1/labels\000027.txt
# Normalized labels for valid1/labels\000028.txt -> valid1/labels\000028.txt
# Normalized labels for valid1/labels\000029.txt -> valid1/labels\000029.txt
# Normalized labels for valid1/labels\000030.txt -> valid1/labels\000030.txt
# Normalized labels for valid1/labels\000031.txt -> valid1/labels\000031.txt
# Normalized labels for valid1/labels\000032.txt -> valid1/labels\000032.txt
# Normalized labels for valid1/labels\000033.txt -> valid1/labels\000033.txt
# Normalized labels for valid1/labels\000034.txt -> valid1/labels\000034.txt
# Normalized labels for valid1/labels\000035.txt -> valid1/labels\000035.txt
# Normalized labels for valid1/labels\000036.txt -> valid1/labels\000036.txt
# Normalized labels for valid1/labels\000037.txt -> valid1/labels\000037.txt
# Normalized labels for valid1/labels\000038.txt -> valid1/labels\000038.txt
# Normalized labels for valid1/labels\000039.txt -> valid1/labels\000039.txt
# Normalized labels for valid1/labels\000040.txt -> valid1/labels\000040.txt
# Normalized labels for valid1/labels\000041.txt -> valid1/labels\000041.txt
# Normalized labels for valid1/labels\000042.txt -> valid1/labels\000042.txt
# Normalized labels for valid1/labels\000043.txt -> valid1/labels\000043.txt
# Normalized labels for valid1/labels\000044.txt -> valid1/labels\000044.txt
# Normalized labels for valid1/labels\000045.txt -> valid1/labels\000045.txt
# Normalized labels for valid1/labels\000046.txt -> valid1/labels\000046.txt
# Normalized labels for valid1/labels\000047.txt -> valid1/labels\000047.txt
# Normalized labels for valid1/labels\000048.txt -> valid1/labels\000048.txt
# Normalized labels for valid1/labels\000049.txt -> valid1/labels\000049.txt
# Normalized labels for valid1/labels\000050.txt -> valid1/labels\000050.txt
# Normalized labels for valid1/labels\000051.txt -> valid1/labels\000051.txt
# Normalized labels for valid1/labels\000052.txt -> valid1/labels\000052.txt
# Normalized labels for valid1/labels\000053.txt -> valid1/labels\000053.txt
# Normalized labels for valid1/labels\000054.txt -> valid1/labels\000054.txt
# Normalized labels for valid1/labels\000055.txt -> valid1/labels\000055.txt
# Normalized labels for valid1/labels\000056.txt -> valid1/labels\000056.txt
# Normalized labels for valid1/labels\000057.txt -> valid1/labels\000057.txt
# Normalized labels for valid1/labels\000058.txt -> valid1/labels\000058.txt
# Normalized labels for valid1/labels\000059.txt -> valid1/labels\000059.txt
# Normalized labels for valid1/labels\000060.txt -> valid1/labels\000060.txt
# Normalized labels for valid1/labels\000061.txt -> valid1/labels\000061.txt
# Normalized labels for valid1/labels\000062.txt -> valid1/labels\000062.txt
# Normalized labels for valid1/labels\000063.txt -> valid1/labels\000063.txt
# Normalized labels for valid1/labels\000064.txt -> valid1/labels\000064.txt
# Normalized labels for valid1/labels\000065.txt -> valid1/labels\000065.txt
# Normalized labels for valid1/labels\000066.txt -> valid1/labels\000066.txt
# Normalized labels for valid1/labels\000067.txt -> valid1/labels\000067.txt
# Normalized labels for valid1/labels\000068.txt -> valid1/labels\000068.txt
# Normalized labels for valid1/labels\000069.txt -> valid1/labels\000069.txt
# Normalized labels for valid1/labels\000070.txt -> valid1/labels\000070.txt
# Normalized labels for valid1/labels\000071.txt -> valid1/labels\000071.txt
# Normalized labels for valid1/labels\000072.txt -> valid1/labels\000072.txt
# Normalized labels for valid1/labels\000073.txt -> valid1/labels\000073.txt
# Normalized labels for valid1/labels\000074.txt -> valid1/labels\000074.txt
# Normalized labels for valid1/labels\000075.txt -> valid1/labels\000075.txt
# Normalized labels for valid1/labels\000076.txt -> valid1/labels\000076.txt
# Normalized labels for valid1/labels\000077.txt -> valid1/labels\000077.txt
# Normalized labels for valid1/labels\000078.txt -> valid1/labels\000078.txt
# Normalized labels for valid1/labels\000079.txt -> valid1/labels\000079.txt
# Normalized labels for valid1/labels\000080.txt -> valid1/labels\000080.txt
# Normalized labels for valid1/labels\000081.txt -> valid1/labels\000081.txt
# Normalized labels for valid1/labels\000082.txt -> valid1/labels\000082.txt
# Normalized labels for valid1/labels\000083.txt -> valid1/labels\000083.txt
# Normalized labels for valid1/labels\000084.txt -> valid1/labels\000084.txt
# Normalized labels for valid1/labels\000085.txt -> valid1/labels\000085.txt
# Normalized labels for valid1/labels\000086.txt -> valid1/labels\000086.txt
# Normalized labels for valid1/labels\000087.txt -> valid1/labels\000087.txt
# Normalized labels for valid1/labels\000088.txt -> valid1/labels\000088.txt
# Normalized labels for valid1/labels\000089.txt -> valid1/labels\000089.txt
# Normalized labels for valid1/labels\000090.txt -> valid1/labels\000090.txt
# Normalized labels for valid1/labels\000091.txt -> valid1/labels\000091.txt
# Normalized labels for valid1/labels\000092.txt -> valid1/labels\000092.txt
# Normalized labels for valid1/labels\000093.txt -> valid1/labels\000093.txt
# Normalized labels for valid1/labels\000094.txt -> valid1/labels\000094.txt
# Normalized labels for valid1/labels\000095.txt -> valid1/labels\000095.txt
# Normalized labels for valid1/labels\000096.txt -> valid1/labels\000096.txt
# Normalized labels for valid1/labels\000097.txt -> valid1/labels\000097.txt
# Normalized labels for valid1/labels\000098.txt -> valid1/labels\000098.txt
# Normalized labels for valid1/labels\000099.txt -> valid1/labels\000099.txt
# Normalized labels for valid1/labels\000100.txt -> valid1/labels\000100.txt
# Normalized labels for valid1/labels\000101.txt -> valid1/labels\000101.txt
# Normalized labels for valid1/labels\000102.txt -> valid1/labels\000102.txt
# Normalized labels for valid1/labels\000103.txt -> valid1/labels\000103.txt
# Normalized labels for valid1/labels\000104.txt -> valid1/labels\000104.txt
# Normalized labels for valid1/labels\000105.txt -> valid1/labels\000105.txt
# Normalized labels for valid1/labels\000106.txt -> valid1/labels\000106.txt
# Normalized labels for valid1/labels\000107.txt -> valid1/labels\000107.txt
# Normalized labels for valid1/labels\000108.txt -> valid1/labels\000108.txt
# Normalized labels for valid1/labels\000109.txt -> valid1/labels\000109.txt
# Normalized labels for valid1/labels\000110.txt -> valid1/labels\000110.txt
# Normalized labels for valid1/labels\000111.txt -> valid1/labels\000111.txt
# Normalized labels for valid1/labels\000112.txt -> valid1/labels\000112.txt
# Normalized labels for valid1/labels\000113.txt -> valid1/labels\000113.txt
# Normalized labels for valid1/labels\000114.txt -> valid1/labels\000114.txt
# Normalized labels for valid1/labels\000115.txt -> valid1/labels\000115.txt
# Normalized labels for valid1/labels\000116.txt -> valid1/labels\000116.txt
# Normalized labels for valid1/labels\000117.txt -> valid1/labels\000117.txt
# Normalized labels for valid1/labels\000118.txt -> valid1/labels\000118.txt
# Normalized labels for valid1/labels\000119.txt -> valid1/labels\000119.txt
# Normalized labels for valid1/labels\000120.txt -> valid1/labels\000120.txt
# Normalized labels for valid1/labels\000121.txt -> valid1/labels\000121.txt
# Normalized labels for valid1/labels\000122.txt -> valid1/labels\000122.txt
# Normalized labels for valid1/labels\000123.txt -> valid1/labels\000123.txt
# Normalized labels for valid1/labels\000124.txt -> valid1/labels\000124.txt
# Normalized labels for valid1/labels\000125.txt -> valid1/labels\000125.txt
# Normalized labels for valid1/labels\000126.txt -> valid1/labels\000126.txt
# Normalized labels for valid1/labels\000127.txt -> valid1/labels\000127.txt
# Normalized labels for valid1/labels\000128.txt -> valid1/labels\000128.txt
# Normalized labels for valid1/labels\000129.txt -> valid1/labels\000129.txt
# Normalized labels for valid1/labels\000130.txt -> valid1/labels\000130.txt
# Normalized labels for valid1/labels\000131.txt -> valid1/labels\000131.txt
# Normalized labels for valid1/labels\000132.txt -> valid1/labels\000132.txt
# Normalized labels for valid1/labels\000133.txt -> valid1/labels\000133.txt
# Normalized labels for valid1/labels\000134.txt -> valid1/labels\000134.txt
# Normalized labels for valid1/labels\000135.txt -> valid1/labels\000135.txt
# Normalized labels for valid1/labels\000136.txt -> valid1/labels\000136.txt
# Normalized labels for valid1/labels\000137.txt -> valid1/labels\000137.txt
# Normalized labels for valid1/labels\000138.txt -> valid1/labels\000138.txt
# Normalized labels for valid1/labels\000139.txt -> valid1/labels\000139.txt
# Normalized labels for valid1/labels\000140.txt -> valid1/labels\000140.txt
# Normalized labels for valid1/labels\000141.txt -> valid1/labels\000141.txt
# Normalized labels for valid1/labels\000142.txt -> valid1/labels\000142.txt
# Normalized labels for valid1/labels\000143.txt -> valid1/labels\000143.txt
# Normalized labels for valid1/labels\000144.txt -> valid1/labels\000144.txt
