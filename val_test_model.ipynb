# %% [markdown]
# ### Validation of different models on seq 1 and 2 images
#
# Best model : best.pt

# %%
from ultralytics import YOLO

# Load the trained model

#model_path = r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\job2\yolov8x.pt"
#model_path = r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\job2\yolo11n.pt"
model_path = r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\job2\runs\detect\train\weights\best.pt" 
#model_path = r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\job2\runs\detect\train\weights\last.pt" 

data_yaml = r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\data_split.yaml"  # Update with the actual path

model = YOLO(model_path)

# Evaluate the model
results = model.val(data=data_yaml, imgsz=640, batch=4)

print("Evaluation results:")
print(results)
# Out:
# Ultralytics 8.3.35  Python-3.10.15 torch-2.5.1+cpu CPU (Intel Core(TM) i7-1065G7 1.30GHz)
# Model summary (fused): 268 layers, 68,126,457 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_01\image_02\labels\data.cache... 145 images, 209 backgrounds, 0 corrupt: 100%|██████████| 354/354 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 89/89 [02:54<00:00,  1.96s/it]
#                    all        354        883      0.251      0.265      0.225     0.0876
#             pedestrian        145        782      0.501      0.531      0.448      0.175
#                cyclist         93        101          0          0    0.00143   0.000236
# Speed: 0.4ms preprocess, 468.1ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs\detect\val
# Evaluation results:
# ...

# %% [markdown]
# ### Model Prediction

# %%
# Predict for seq 2

model.predict(
    task='detect',
    model = r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\job2\runs\detect\train\weights\best.pt",
    source= r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_02\image_02\images\data",
    imgsz=640,
    save=True,
    save_txt=True
)
# Out:
# image 1/209 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_02\image_02\images\data\0000000000.png: 224x640 8 pedestrians, 2 cyclists, 4 cars, 429.7ms
# image 2/209 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_02\image_02\images\data\0000000001.png: 224x640 10 pedestrians, 2 cyclists, 4 cars, 394.0ms
# image 3/209 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_02\image_02\images\data\0000000002.png: 224x640 12 pedestrians, 2 cyclists, 4 cars, 421.2ms
# image 4/209 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_02\image_02\images\data\0000000003.png: 224x640 14 pedestrians, 2 cyclists, 4 cars, 395.0ms
# ...

# %%
# Predict for seq 3

model.predict(
    task='detect',
    model = r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\job2\runs\detect\train\weights\best.pt",
    source= r"C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_03\image_02\images\data",
    imgsz=640,
    save=True,
    save_txt=True
)
# Out:
# image 1/286 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_03\image_02\images\data\0000000000.png: 224x640 5 pedestrians, 4 cars, 771.0ms
# image 2/286 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_03\image_02\images\data\0000000001.png: 224x640 4 pedestrians, 4 cars, 443.0ms
# image 3/286 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_03\image_02\images\data\0000000002.png: 224x640 4 pedestrians, 4 cars, 488.8ms
# image 4/286 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_03\image_02\images\data\0000000003.png: 224x640 4 pedestrians, 4 cars, 370.7ms
# image 5/286 C:\Users\ongji\OneDrive\Documents\DTU\34759 Perception for Autonomous Systems\Rectified_images\seq_03\image_02\images\data\0000000004.png: 224x640 3 pedestrians, 3 cars, 479.0ms
# ...
